# %%
import pandas as pd

# %%
rankings = pd.read_csv("c:\\users\\robert\\desktop\\Americas health rankings 2018-2020\\2019-Annual.csv")
rankings.head()
# Out:
#    Edition  Report Type                   Measure Name     State Name  Rank  \
# 0     2019  2019 Annual  Adverse Childhood Experiences         Alaska  34.0
# 1     2019  2019 Annual  Adverse Childhood Experiences        Alabama  46.0
# 2     2019  2019 Annual  Adverse Childhood Experiences  United States   NaN
# 3     2019  2019 Annual  Adverse Childhood Experiences       Arkansas  47.0
# 4     2019  2019 Annual  Adverse Childhood Experiences        Arizona  48.0
#
#    Value  Score  Lower CI  Upper CI    Source Source Year
# 0   24.1   0.96      27.7      20.5  AHR data         NaN
# 1   26.3   1.56      30.1      22.5  AHR data         NaN
# 2   20.5    NaN      21.2      19.8  AHR data         NaN
# 3   27.1   1.76      30.8      23.3  AHR data         NaN
# 4   27.3   1.82      31.1      23.4  AHR data         NaN

# %%
cols =[
'Adverse Childhood Experiences',
'Avoided Care Due to Cost',
'Childhood Immunizations',
'Colorectal Cancer Screening',
'Dedicated Health Care Provider',
'Dental Care Providers',
'Depression',
'Drinking Water Violations',
'Drive Alone to Work',
'Drug Deaths (1-year)',
'Excessive Drinking',
'Exercise',
'Flu Vaccination',
'Food Insecurity',
'Frequent Mental Distress',
'Frequent Physical Distress',
'High-speed Internet',
'Illicit Drug Use (excluding opioids and cannabis)',
'Income Inequality',
'Low Birthweight',
'Mental Health Providers',
'Mortality - Annual',
'Multiple Chronic Conditions',
'Non-medical Drug Use',
'Nutrition and Physical Activity',
'Obesity',
'Physical Inactivity',
'Premature Death',
'Preventable Hospitalizations',
'Primary Care Providers',
'Public Health Funding',
'Smoking',
'Teen Births',
'Uninsured',
'Violent Crime',
'Volunteerism',
'Voter Participation (Midterm)',
'Voter Participation (Presidential)'
]

# %%
import os
for c in cols:
    this_df=rankings[rankings['Measure Name']==c]
    this_df.to_csv(os.path.join("c:\\users\\robert\\desktop\\health", "state_data_"+c +"_2019" + ".csv"))

# %%
.
